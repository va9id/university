# %% [markdown]
# # Question 1

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
torch.cuda.is_available()

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the CNN Class
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # Step 1: Create the first convolutional layer (conv1)
        #   - Input channels: 3
        #   - Output channels: 6
        #   - Kernel size: 5
        self.conv1 = nn.Conv2d(3, 6, 5)

        # Step 2: Create max pooling layer (pool)
        #   - Kernel size: 2
        #   - Stride: 2
        self.pool = nn.MaxPool2d(2, 2)
        # Step 3: Create the second convolutional layer (conv2)
        #   - Input channels: 6
        #   - Output channels: 16
        #   - Kernel size: 5
        self.conv2 = nn.Conv2d(6, 16, 5)

        # Step 4: Create the first fully connected layer (fc1)
        #   - Input features: 16 * 5 * 5
        #   - Output features: 120
        self.fc1 = nn.Linear(16 * 5 * 5, 120)

        # Step 5: Create the second fully connected layer (fc2)
        #   - Input features: 120
        #   - Output features: 120
        self.fc2 = nn.Linear(120, 120)

        # Step 6: Create the third fully connected layer (fc3)
        #   - Input features: 120
        #   - Output features: 10 (number of classes in CIFAR-10)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        # Step 7: Define the forward pass
        #   - Apply conv1, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        #   - Apply conv2, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        #   - Reshape the tensor for the fully connected layers
        x = x.view(-1, 16 * 5 * 5)
        #   - Apply fc1, followed by ReLU activation
        x = F.relu(self.fc1(x))
        #   - Apply fc2, followed by ReLU activation
        x = F.relu(self.fc2(x))
        #   - Apply fc3 (output layer)
        x = self.fc3(x)
        #   - Return output
        return x
print(Net())
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### Simple Neural Network with 0 hidden layers

# %%
class SimpleNN0(nn.Module):
    def __init__(self):
        super(SimpleNN0, self).__init__()
        self.img_size = 32 * 32 * 3
        # Output Layer
        self.fc1 = nn.Linear(self.img_size, 10)

    def forward(self, x):
        x = x.view(-1, self.img_size)
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)
    
print(SimpleNN0())
# Out:
# SimpleNN0(
#   (fc1): Linear(in_features=3072, out_features=10, bias=True)
# )

# %% [markdown]
# ### Simple Neural Network with 1 hidden layer

# %%
class SimpleNN1(nn.Module):
    def __init__(self):
        super(SimpleNN1, self).__init__()
        self.img_size = 32 * 32 * 3
        # Hidden layer
        self.fc1 = nn.Linear(self.img_size, 120)
        self.fc2 = nn.Linear(120, 10)

    def forward(self, x):
        x = x.view(-1, self.img_size)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)
    
print(SimpleNN1())
# Out:
# SimpleNN1(
#   (fc1): Linear(in_features=3072, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### Simple Neural Network with 2 hidden layers

# %%
class SimpleNN2(nn.Module):
    def __init__(self):
        super(SimpleNN2, self).__init__()
        self.img_size = 32 * 32 * 3
        # Hidden layer
        self.fc1 = nn.Linear(self.img_size, 120)
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        x = x.view(-1, self.img_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)
    
print(SimpleNN2())
# Out:
# SimpleNN2(
#   (fc1): Linear(in_features=3072, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### Simple Neural Network with 3 hidden layers

# %%
class SimpleNN3(nn.Module):
    def __init__(self):
        super(SimpleNN3, self).__init__()
        self.img_size = 32 * 32 * 3
        # Hidden layer
        self.fc1 = nn.Linear(self.img_size, 120)
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 120)
        self.fc4 = nn.Linear(120, 10)

    def forward(self, x):
        x = x.view(-1, self.img_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x
    
print(SimpleNN3())
# Out:
# SimpleNN3(
#   (fc1): Linear(in_features=3072, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=120, bias=True)
#   (fc4): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### Simple Neural Network with 4 hidden layers

# %%
class SimpleNN4(nn.Module):
    def __init__(self):
        super(SimpleNN4, self).__init__()
        self.img_size = 32 * 32 * 3
        # Hidden layer
        self.fc1 = nn.Linear(self.img_size, 120)
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 120)
        self.fc4 = nn.Linear(120, 120)
        self.fc5 = nn.Linear(120, 10)

    def forward(self, x):
        x = x.view(-1, self.img_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x
    
print(SimpleNN4())
# Out:
# SimpleNN4(
#   (fc1): Linear(in_features=3072, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=120, bias=True)
#   (fc4): Linear(in_features=120, out_features=120, bias=True)
#   (fc5): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
import torch.optim as optim
net=Net()
CUDA=torch.cuda.is_available()
if CUDA:
  net=net.cuda()

# Let's first define our device as the first visible cuda device if we have
# CUDA available:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)

#In Colab, got to Edit>Notebook settings> choose Python 3. For the hardware
#accelerator, you may select None or GPU.
# Out:
# cpu

# %%
# 4. Train the network
def network_training(net): 
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
  accuracy_values=[]
  epoch_number=[]
  for epoch in range(10):  # loop over the dataset multiple times. Here 10 means 10 epochs
      running_loss = 0.0
      for i, (inputs,labels) in enumerate(trainloader, 0):
          # get the inputs; data is a list of [inputs, labels]
          if CUDA:
            inputs = inputs.cuda()
            labels = labels.cuda()
          else:
            inputs = inputs.cpu()
            labels = labels.cpu()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 2000 == 1999:    # print every 2000 mini-batches
              print('[epoch%d, itr%5d] loss: %.3f' %
                    (epoch + 1, i + 1, running_loss / 2000))
              running_loss = 0.0

      correct = 0
      total = 0
      with torch.no_grad():
          for images, labels in testloader:
              if CUDA:
                images = images.cuda()
                labels = labels.cuda()
              else:
                images = images.cpu()
                labels =labels.cpu()

              outputs = net(images)
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              if CUDA:
                correct += (predicted.cpu()==labels.cpu()).sum().item()
              else:
                correct += (predicted==labels).sum().item()

          TestAccuracy = 100 * correct / total;
          epoch_number += [epoch+1]
          accuracy_values += [TestAccuracy]
          print('Epoch=%d Test Accuracy=%.3f' %
                    (epoch + 1, TestAccuracy))

  print('Finished Training')
  return accuracy_values, epoch_number

# %%
import matplotlib.pyplot as plt
import numpy as np

nets = [Net(), SimpleNN0(), SimpleNN1(), SimpleNN2(), SimpleNN3(), SimpleNN4()]
names = ["CCN", "SNN0", "SNN1", "SNN2", "SNN3", "SNN4"]
colors = ["blue", "red", "black", "yellow", "green", "brown"]

for net, name, color in zip(nets, names, colors):
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
    accuracy_values, epoch_number = network_training(net)
    # Plot the data
    plt.plot(epoch_number, accuracy_values, color=color, label=name)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

# Add a legend
plt.legend()

# Show the plot
plt.show()

## Anything better than 10% accuracy (randomly picking a class out of 10 classes)
# means the network has learned something.
## Anything better than 10% accuracy (randomly picking a class out of 10 classes)
# means the network has learned something.
# Out:
# [epoch1, itr 2000] loss: 2.228
# [epoch1, itr 4000] loss: 1.860
# [epoch1, itr 6000] loss: 1.691
# [epoch1, itr 8000] loss: 1.594
# [epoch1, itr10000] loss: 1.502
# [epoch1, itr12000] loss: 1.443
# Epoch=1 Test Accuracy=47.030
# [epoch2, itr 2000] loss: 1.368
# [epoch2, itr 4000] loss: 1.366
# [epoch2, itr 6000] loss: 1.342
# [epoch2, itr 8000] loss: 1.307
# [epoch2, itr10000] loss: 1.309
# [epoch2, itr12000] loss: 1.286
# Epoch=2 Test Accuracy=56.210
# [epoch3, itr 2000] loss: 1.227
# [epoch3, itr 4000] loss: 1.195
# [epoch3, itr 6000] loss: 1.210
# [epoch3, itr 8000] loss: 1.199
# [epoch3, itr10000] loss: 1.196
# [epoch3, itr12000] loss: 1.184
# Epoch=3 Test Accuracy=59.140
# [epoch4, itr 2000] loss: 1.120
# [epoch4, itr 4000] loss: 1.112
# [epoch4, itr 6000] loss: 1.100
# [epoch4, itr 8000] loss: 1.097
# [epoch4, itr10000] loss: 1.113
# [epoch4, itr12000] loss: 1.117
# Epoch=4 Test Accuracy=60.010
# [epoch5, itr 2000] loss: 1.018
# [epoch5, itr 4000] loss: 1.025
# [epoch5, itr 6000] loss: 1.044
# [epoch5, itr 8000] loss: 1.027
# [epoch5, itr10000] loss: 1.052
# [epoch5, itr12000] loss: 1.062
# Epoch=5 Test Accuracy=60.560
# [epoch6, itr 2000] loss: 0.959
# [epoch6, itr 4000] loss: 0.975
# [epoch6, itr 6000] loss: 0.980
# [epoch6, itr 8000] loss: 1.007
# [epoch6, itr10000] loss: 0.977
# [epoch6, itr12000] loss: 1.017
# Epoch=6 Test Accuracy=60.430
# [epoch7, itr 2000] loss: 0.913
# [epoch7, itr 4000] loss: 0.935
# [epoch7, itr 6000] loss: 0.925
# [epoch7, itr 8000] loss: 0.936
# [epoch7, itr10000] loss: 0.969
# [epoch7, itr12000] loss: 0.958
# Epoch=7 Test Accuracy=61.150
# [epoch8, itr 2000] loss: 0.858
# [epoch8, itr 4000] loss: 0.873
# [epoch8, itr 6000] loss: 0.892
# [epoch8, itr 8000] loss: 0.902
# [epoch8, itr10000] loss: 0.939
# [epoch8, itr12000] loss: 0.917
# Epoch=8 Test Accuracy=59.520
# [epoch9, itr 2000] loss: 0.809
# [epoch9, itr 4000] loss: 0.825
# [epoch9, itr 6000] loss: 0.856
# [epoch9, itr 8000] loss: 0.866
# [epoch9, itr10000] loss: 0.893
# [epoch9, itr12000] loss: 0.889
# Epoch=9 Test Accuracy=61.040
# [epoch10, itr 2000] loss: 0.788
# [epoch10, itr 4000] loss: 0.803
# [epoch10, itr 6000] loss: 0.828
# [epoch10, itr 8000] loss: 0.846
# [epoch10, itr10000] loss: 0.861
# [epoch10, itr12000] loss: 0.858
# Epoch=10 Test Accuracy=62.490
# Finished Training
# [epoch1, itr 2000] loss: 2.171
# [epoch1, itr 4000] loss: 2.172
# [epoch1, itr 6000] loss: 2.144
# [epoch1, itr 8000] loss: 2.157
# [epoch1, itr10000] loss: 2.140
# [epoch1, itr12000] loss: 2.149
# Epoch=1 Test Accuracy=33.910
# [epoch2, itr 2000] loss: 2.084
# [epoch2, itr 4000] loss: 2.093
# [epoch2, itr 6000] loss: 2.135
# [epoch2, itr 8000] loss: 2.107
# [epoch2, itr10000] loss: 2.057
# [epoch2, itr12000] loss: 2.082
# Epoch=2 Test Accuracy=31.510
# [epoch3, itr 2000] loss: 2.061
# [epoch3, itr 4000] loss: 2.066
# [epoch3, itr 6000] loss: 2.074
# [epoch3, itr 8000] loss: 2.102
# [epoch3, itr10000] loss: 2.110
# [epoch3, itr12000] loss: 2.099
# Epoch=3 Test Accuracy=32.030
# [epoch4, itr 2000] loss: 2.027
# [epoch4, itr 4000] loss: 2.058
# [epoch4, itr 6000] loss: 2.077
# [epoch4, itr 8000] loss: 2.070
# [epoch4, itr10000] loss: 2.083
# [epoch4, itr12000] loss: 2.083
# Epoch=4 Test Accuracy=34.180
# [epoch5, itr 2000] loss: 2.047
# [epoch5, itr 4000] loss: 2.063
# [epoch5, itr 6000] loss: 2.055
# [epoch5, itr 8000] loss: 2.080
# [epoch5, itr10000] loss: 2.056
# [epoch5, itr12000] loss: 2.076
# Epoch=5 Test Accuracy=33.780
# [epoch6, itr 2000] loss: 1.991
# [epoch6, itr 4000] loss: 2.042
# [epoch6, itr 6000] loss: 2.068
# [epoch6, itr 8000] loss: 2.067
# [epoch6, itr10000] loss: 2.072
# [epoch6, itr12000] loss: 2.053
# Epoch=6 Test Accuracy=33.170
# [epoch7, itr 2000] loss: 2.030
# [epoch7, itr 4000] loss: 2.018
# [epoch7, itr 6000] loss: 2.048
# [epoch7, itr 8000] loss: 2.052
# [epoch7, itr10000] loss: 2.081
# [epoch7, itr12000] loss: 2.064
# Epoch=7 Test Accuracy=30.580
# [epoch8, itr 2000] loss: 2.002
# [epoch8, itr 4000] loss: 2.013
# [epoch8, itr 6000] loss: 2.047
# [epoch8, itr 8000] loss: 2.031
# [epoch8, itr10000] loss: 2.049
# [epoch8, itr12000] loss: 2.067
# Epoch=8 Test Accuracy=33.880
# [epoch9, itr 2000] loss: 2.002
# [epoch9, itr 4000] loss: 2.039
# [epoch9, itr 6000] loss: 2.015
# [epoch9, itr 8000] loss: 2.050
# [epoch9, itr10000] loss: 2.040
# [epoch9, itr12000] loss: 2.039
# Epoch=9 Test Accuracy=33.060
# [epoch10, itr 2000] loss: 1.979
# [epoch10, itr 4000] loss: 2.003
# [epoch10, itr 6000] loss: 1.998
# [epoch10, itr 8000] loss: 2.068
# [epoch10, itr10000] loss: 2.080
# [epoch10, itr12000] loss: 2.051
# Epoch=10 Test Accuracy=31.990
# Finished Training
# [epoch1, itr 2000] loss: 1.850
# [epoch1, itr 4000] loss: 1.692
# [epoch1, itr 6000] loss: 1.647
# [epoch1, itr 8000] loss: 1.627
# [epoch1, itr10000] loss: 1.588
# [epoch1, itr12000] loss: 1.585
# Epoch=1 Test Accuracy=45.750
# [epoch2, itr 2000] loss: 1.491
# [epoch2, itr 4000] loss: 1.507
# [epoch2, itr 6000] loss: 1.497
# [epoch2, itr 8000] loss: 1.507
# [epoch2, itr10000] loss: 1.515
# [epoch2, itr12000] loss: 1.488
# Epoch=2 Test Accuracy=47.170
# [epoch3, itr 2000] loss: 1.408
# [epoch3, itr 4000] loss: 1.413
# [epoch3, itr 6000] loss: 1.437
# [epoch3, itr 8000] loss: 1.448
# [epoch3, itr10000] loss: 1.433
# [epoch3, itr12000] loss: 1.414
# Epoch=3 Test Accuracy=48.710
# [epoch4, itr 2000] loss: 1.354
# [epoch4, itr 4000] loss: 1.354
# [epoch4, itr 6000] loss: 1.382
# [epoch4, itr 8000] loss: 1.377
# [epoch4, itr10000] loss: 1.386
# [epoch4, itr12000] loss: 1.414
# Epoch=4 Test Accuracy=49.430
# [epoch5, itr 2000] loss: 1.317
# [epoch5, itr 4000] loss: 1.300
# [epoch5, itr 6000] loss: 1.341
# [epoch5, itr 8000] loss: 1.309
# [epoch5, itr10000] loss: 1.344
# [epoch5, itr12000] loss: 1.364
# Epoch=5 Test Accuracy=49.190
# [epoch6, itr 2000] loss: 1.252
# [epoch6, itr 4000] loss: 1.293
# [epoch6, itr 6000] loss: 1.277
# [epoch6, itr 8000] loss: 1.300
# [epoch6, itr10000] loss: 1.298
# [epoch6, itr12000] loss: 1.323
# Epoch=6 Test Accuracy=49.420
# [epoch7, itr 2000] loss: 1.214
# [epoch7, itr 4000] loss: 1.257
# [epoch7, itr 6000] loss: 1.246
# [epoch7, itr 8000] loss: 1.272
# [epoch7, itr10000] loss: 1.284
# [epoch7, itr12000] loss: 1.287
# Epoch=7 Test Accuracy=49.190
# [epoch8, itr 2000] loss: 1.208
# [epoch8, itr 4000] loss: 1.203
# [epoch8, itr 6000] loss: 1.237
# [epoch8, itr 8000] loss: 1.230
# [epoch8, itr10000] loss: 1.241
# [epoch8, itr12000] loss: 1.261
# Epoch=8 Test Accuracy=49.610
# [epoch9, itr 2000] loss: 1.149
# [epoch9, itr 4000] loss: 1.168
# [epoch9, itr 6000] loss: 1.200
# [epoch9, itr 8000] loss: 1.224
# [epoch9, itr10000] loss: 1.185
# [epoch9, itr12000] loss: 1.254
# Epoch=9 Test Accuracy=48.780
# [epoch10, itr 2000] loss: 1.139
# [epoch10, itr 4000] loss: 1.155
# [epoch10, itr 6000] loss: 1.171
# [epoch10, itr 8000] loss: 1.168
# [epoch10, itr10000] loss: 1.202
# [epoch10, itr12000] loss: 1.196
# Epoch=10 Test Accuracy=50.340
# Finished Training
# [epoch1, itr 2000] loss: 1.938
# [epoch1, itr 4000] loss: 1.727
# [epoch1, itr 6000] loss: 1.659
# [epoch1, itr 8000] loss: 1.600
# [epoch1, itr10000] loss: 1.569
# [epoch1, itr12000] loss: 1.571
# Epoch=1 Test Accuracy=46.070
# [epoch2, itr 2000] loss: 1.472
# [epoch2, itr 4000] loss: 1.482
# [epoch2, itr 6000] loss: 1.472
# [epoch2, itr 8000] loss: 1.455
# [epoch2, itr10000] loss: 1.437
# [epoch2, itr12000] loss: 1.434
# Epoch=2 Test Accuracy=49.340
# [epoch3, itr 2000] loss: 1.375
# [epoch3, itr 4000] loss: 1.380
# [epoch3, itr 6000] loss: 1.375
# [epoch3, itr 8000] loss: 1.370
# [epoch3, itr10000] loss: 1.358
# [epoch3, itr12000] loss: 1.360
# Epoch=3 Test Accuracy=50.840
# [epoch4, itr 2000] loss: 1.271
# [epoch4, itr 4000] loss: 1.308
# [epoch4, itr 6000] loss: 1.324
# [epoch4, itr 8000] loss: 1.296
# [epoch4, itr10000] loss: 1.310
# [epoch4, itr12000] loss: 1.300
# Epoch=4 Test Accuracy=51.530
# [epoch5, itr 2000] loss: 1.224
# [epoch5, itr 4000] loss: 1.225
# [epoch5, itr 6000] loss: 1.253
# [epoch5, itr 8000] loss: 1.238
# [epoch5, itr10000] loss: 1.258
# [epoch5, itr12000] loss: 1.266
# Epoch=5 Test Accuracy=50.400
# [epoch6, itr 2000] loss: 1.154
# [epoch6, itr 4000] loss: 1.192
# [epoch6, itr 6000] loss: 1.198
# [epoch6, itr 8000] loss: 1.206
# [epoch6, itr10000] loss: 1.214
# [epoch6, itr12000] loss: 1.221
# Epoch=6 Test Accuracy=52.470
# [epoch7, itr 2000] loss: 1.114
# [epoch7, itr 4000] loss: 1.142
# [epoch7, itr 6000] loss: 1.157
# [epoch7, itr 8000] loss: 1.176
# [epoch7, itr10000] loss: 1.180
# [epoch7, itr12000] loss: 1.172
# Epoch=7 Test Accuracy=52.460
# [epoch8, itr 2000] loss: 1.071
# [epoch8, itr 4000] loss: 1.104
# [epoch8, itr 6000] loss: 1.109
# [epoch8, itr 8000] loss: 1.142
# [epoch8, itr10000] loss: 1.126
# [epoch8, itr12000] loss: 1.136
# Epoch=8 Test Accuracy=52.300
# [epoch9, itr 2000] loss: 1.012
# [epoch9, itr 4000] loss: 1.085
# [epoch9, itr 6000] loss: 1.062
# [epoch9, itr 8000] loss: 1.100
# [epoch9, itr10000] loss: 1.094
# [epoch9, itr12000] loss: 1.131
# Epoch=9 Test Accuracy=50.410
# [epoch10, itr 2000] loss: 1.005
# [epoch10, itr 4000] loss: 1.048
# [epoch10, itr 6000] loss: 1.032
# [epoch10, itr 8000] loss: 1.066
# [epoch10, itr10000] loss: 1.053
# [epoch10, itr12000] loss: 1.081
# Epoch=10 Test Accuracy=52.510
# Finished Training
# [epoch1, itr 2000] loss: 2.059
# [epoch1, itr 4000] loss: 1.791
# [epoch1, itr 6000] loss: 1.690
# [epoch1, itr 8000] loss: 1.643
# [epoch1, itr10000] loss: 1.611
# [epoch1, itr12000] loss: 1.575
# Epoch=1 Test Accuracy=44.550
# [epoch2, itr 2000] loss: 1.517
# [epoch2, itr 4000] loss: 1.509
# [epoch2, itr 6000] loss: 1.502
# [epoch2, itr 8000] loss: 1.429
# [epoch2, itr10000] loss: 1.477
# [epoch2, itr12000] loss: 1.449
# Epoch=2 Test Accuracy=47.890
# [epoch3, itr 2000] loss: 1.384
# [epoch3, itr 4000] loss: 1.374
# [epoch3, itr 6000] loss: 1.369
# [epoch3, itr 8000] loss: 1.366
# [epoch3, itr10000] loss: 1.366
# [epoch3, itr12000] loss: 1.375
# Epoch=3 Test Accuracy=49.630
# [epoch4, itr 2000] loss: 1.288
# [epoch4, itr 4000] loss: 1.293
# [epoch4, itr 6000] loss: 1.300
# [epoch4, itr 8000] loss: 1.320
# [epoch4, itr10000] loss: 1.297
# [epoch4, itr12000] loss: 1.286
# Epoch=4 Test Accuracy=51.200
# [epoch5, itr 2000] loss: 1.217
# [epoch5, itr 4000] loss: 1.220
# [epoch5, itr 6000] loss: 1.231
# [epoch5, itr 8000] loss: 1.242
# [epoch5, itr10000] loss: 1.263
# [epoch5, itr12000] loss: 1.232
# Epoch=5 Test Accuracy=52.690
# [epoch6, itr 2000] loss: 1.147
# [epoch6, itr 4000] loss: 1.191
# [epoch6, itr 6000] loss: 1.181
# [epoch6, itr 8000] loss: 1.205
# [epoch6, itr10000] loss: 1.184
# [epoch6, itr12000] loss: 1.208
# Epoch=6 Test Accuracy=52.160
# [epoch7, itr 2000] loss: 1.115
# [epoch7, itr 4000] loss: 1.127
# [epoch7, itr 6000] loss: 1.148
# [epoch7, itr 8000] loss: 1.153
# [epoch7, itr10000] loss: 1.147
# [epoch7, itr12000] loss: 1.151
# Epoch=7 Test Accuracy=52.350
# [epoch8, itr 2000] loss: 1.053
# [epoch8, itr 4000] loss: 1.093
# [epoch8, itr 6000] loss: 1.096
# [epoch8, itr 8000] loss: 1.110
# [epoch8, itr10000] loss: 1.122
# [epoch8, itr12000] loss: 1.112
# Epoch=8 Test Accuracy=52.460
# [epoch9, itr 2000] loss: 1.024
# [epoch9, itr 4000] loss: 1.068
# [epoch9, itr 6000] loss: 1.058
# [epoch9, itr 8000] loss: 1.076
# [epoch9, itr10000] loss: 1.087
# [epoch9, itr12000] loss: 1.073
# Epoch=9 Test Accuracy=52.990
# [epoch10, itr 2000] loss: 0.990
# [epoch10, itr 4000] loss: 1.009
# [epoch10, itr 6000] loss: 1.056
# [epoch10, itr 8000] loss: 1.026
# [epoch10, itr10000] loss: 1.055
# [epoch10, itr12000] loss: 1.045
# Epoch=10 Test Accuracy=52.100
# Finished Training
# [epoch1, itr 2000] loss: 2.187
# [epoch1, itr 4000] loss: 1.886
# [epoch1, itr 6000] loss: 1.750
# [epoch1, itr 8000] loss: 1.697
# [epoch1, itr10000] loss: 1.657
# [epoch1, itr12000] loss: 1.610
# Epoch=1 Test Accuracy=44.470
# [epoch2, itr 2000] loss: 1.556
# [epoch2, itr 4000] loss: 1.526
# [epoch2, itr 6000] loss: 1.503
# [epoch2, itr 8000] loss: 1.485
# [epoch2, itr10000] loss: 1.490
# [epoch2, itr12000] loss: 1.473
# Epoch=2 Test Accuracy=48.870
# [epoch3, itr 2000] loss: 1.403
# [epoch3, itr 4000] loss: 1.387
# [epoch3, itr 6000] loss: 1.395
# [epoch3, itr 8000] loss: 1.384
# [epoch3, itr10000] loss: 1.400
# [epoch3, itr12000] loss: 1.379
# Epoch=3 Test Accuracy=49.220
# [epoch4, itr 2000] loss: 1.300
# [epoch4, itr 4000] loss: 1.320
# [epoch4, itr 6000] loss: 1.317
# [epoch4, itr 8000] loss: 1.313
# [epoch4, itr10000] loss: 1.316
# [epoch4, itr12000] loss: 1.320
# Epoch=4 Test Accuracy=50.710
# [epoch5, itr 2000] loss: 1.234
# [epoch5, itr 4000] loss: 1.250
# [epoch5, itr 6000] loss: 1.268
# [epoch5, itr 8000] loss: 1.241
# [epoch5, itr10000] loss: 1.253
# [epoch5, itr12000] loss: 1.260
# Epoch=5 Test Accuracy=50.910
# [epoch6, itr 2000] loss: 1.190
# [epoch6, itr 4000] loss: 1.194
# [epoch6, itr 6000] loss: 1.176
# [epoch6, itr 8000] loss: 1.225
# [epoch6, itr10000] loss: 1.202
# [epoch6, itr12000] loss: 1.215
# Epoch=6 Test Accuracy=51.360
# [epoch7, itr 2000] loss: 1.137
# [epoch7, itr 4000] loss: 1.139
# [epoch7, itr 6000] loss: 1.154
# [epoch7, itr 8000] loss: 1.138
# [epoch7, itr10000] loss: 1.165
# [epoch7, itr12000] loss: 1.178
# Epoch=7 Test Accuracy=52.120
# [epoch8, itr 2000] loss: 1.090
# [epoch8, itr 4000] loss: 1.106
# [epoch8, itr 6000] loss: 1.107
# [epoch8, itr 8000] loss: 1.106
# [epoch8, itr10000] loss: 1.125
# [epoch8, itr12000] loss: 1.138
# Epoch=8 Test Accuracy=52.150
# [epoch9, itr 2000] loss: 1.032
# [epoch9, itr 4000] loss: 1.067
# [epoch9, itr 6000] loss: 1.075
# [epoch9, itr 8000] loss: 1.096
# [epoch9, itr10000] loss: 1.082
# [epoch9, itr12000] loss: 1.109
# Epoch=9 Test Accuracy=51.710
# [epoch10, itr 2000] loss: 0.998
# [epoch10, itr 4000] loss: 1.015
# [epoch10, itr 6000] loss: 1.029
# [epoch10, itr 8000] loss: 1.032
# [epoch10, itr10000] loss: 1.058
# [epoch10, itr12000] loss: 1.073
# Epoch=10 Test Accuracy=52.090
# Finished Training

# %% [markdown]
# #Additional code to explore the dataset and the trained model

# %%
# Show some random training images

import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.size())
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# torch.Size([4, 3, 32, 32])
#  deer  ship  bird   dog

# %%
# Test the network on some test images

dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))

# The outputs are energies for the 10 classes.
# The higher the energy for a class, the more the network
# thinks that the image is of the particular class.
# So, let's get the index of the highest energy:
if CUDA:
  images = images.cuda()
  labels = labels.cuda()
else:
  images = images.cpu()
  labels =labels.cpu()
outputs = net(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship   car plane

# %%
# Lets check what are the classes that performed well, and the classes that did
# not perform well:

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for images, labels in testloader:
        if CUDA:
          images =images.cuda()
          labels =labels.cuda()
        else:
          images =images.cpu()
          labels =labels.cpu()

        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 56 %
# Accuracy of   car : 60 %
# Accuracy of  bird : 46 %
# Accuracy of   cat : 38 %
# Accuracy of  deer : 51 %
# Accuracy of   dog : 19 %
# Accuracy of  frog : 52 %
# Accuracy of horse : 62 %
# Accuracy of  ship : 70 %
# Accuracy of truck : 61 %

# %% [markdown]
# # Question 2

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
torch.cuda.is_available()

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the CNN Class
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # Step 1: Create the first convolutional layer (conv1)
        #   - Input channels: 3
        #   - Output channels: 6
        #   - Kernel size: 5
        self.conv1 = nn.Conv2d(3, 6, 5)

        # Step 2: Create max pooling layer (pool)
        #   - Kernel size: 2
        #   - Stride: 2
        self.pool = nn.MaxPool2d(2, 2)
        # Step 3: Create the second convolutional layer (conv2)
        #   - Input channels: 6
        #   - Output channels: 16
        #   - Kernel size: 5
        self.conv2 = nn.Conv2d(6, 16, 5)

        # Step 4: Create the first fully connected layer (fc1)
        #   - Input features: 16 * 5 * 5
        #   - Output features: 120
        self.fc1 = nn.Linear(16 * 5 * 5, 120)

        # Step 5: Create the second fully connected layer (fc2)
        #   - Input features: 120
        #   - Output features: 120
        self.fc2 = nn.Linear(120, 120)

        # Step 6: Create the third fully connected layer (fc3)
        #   - Input features: 120
        #   - Output features: 10 (number of classes in CIFAR-10)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        # Step 7: Define the forward pass
        #   - Apply conv1, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        #   - Apply conv2, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        #   - Reshape the tensor for the fully connected layers
        x = x.view(-1, 16 * 5 * 5)
        #   - Apply fc1, followed by ReLU activation
        x = F.relu(self.fc1(x))
        #   - Apply fc2, followed by ReLU activation
        x = F.relu(self.fc2(x))
        #   - Apply fc3 (output layer)
        x = self.fc3(x)
        #   - Return output
        return x 
print(Net())
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
import torch.optim as optim
net=Net()
CUDA=torch.cuda.is_available()
if CUDA:
  net=net.cuda()

# Let's first define our device as the first visible cuda device if we have
# CUDA available:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)

#In Colab, got to Edit>Notebook settings> choose Python 3. For the hardware
#accelerator, you may select None or GPU.
# Out:
# cpu

# %%
# 4. Train the network
def network_training(learning_rate): 
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
  accuracy_values=[]
  epoch_number=[]
  for epoch in range(10):  # loop over the dataset multiple times. Here 10 means 10 epochs
      running_loss = 0.0
      for i, (inputs,labels) in enumerate(trainloader, 0):
          # get the inputs; data is a list of [inputs, labels]
          if CUDA:
            inputs = inputs.cuda()
            labels = labels.cuda()
          else:
            inputs = inputs.cpu()
            labels = labels.cpu()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 2000 == 1999:    # print every 2000 mini-batches
              print('[epoch%d, itr%5d] loss: %.3f' %
                    (epoch + 1, i + 1, running_loss / 2000))
              running_loss = 0.0

      correct = 0
      total = 0
      with torch.no_grad():
          for images, labels in testloader:
              if CUDA:
                images = images.cuda()
                labels = labels.cuda()
              else:
                images = images.cpu()
                labels =labels.cpu()

              outputs = net(images)
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              if CUDA:
                correct += (predicted.cpu()==labels.cpu()).sum().item()
              else:
                correct += (predicted==labels).sum().item()

          TestAccuracy = 100 * correct / total;
          epoch_number += [epoch+1]
          accuracy_values += [TestAccuracy]
          print('Epoch=%d Test Accuracy=%.3f' %
                    (epoch + 1, TestAccuracy))

  print('Finished Training')
  return accuracy_values, epoch_number

# %%
import matplotlib.pyplot as plt
import numpy as np

learning_rates = [0.0001, 0.001, 0.01, 0.1]
names = ["LR=0.0001", "LR=0.001", "LR=0.01", "LR=0.1"]
colors = ["red", "blue", "green", "yellow"]

for learning_rate, name, color in zip(learning_rates, names, colors): 
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
    accuracy_values, epoch_number = network_training(learning_rate)
    # Plot the data
    plt.plot(epoch_number, accuracy_values, color=color, label=name)

# Add labels
plt.xlabel("Epochs")
plt.ylabel("Accuracy")

# Add a legend
plt.legend()

# Show the plot
plt.show()

## Anything better than 10% accuracy (randomly picking a class out of 10 classes)
# means the network has learned something.
# Out:
# [epoch1, itr 2000] loss: 2.304
# [epoch1, itr 4000] loss: 2.301
# [epoch1, itr 6000] loss: 2.298
# [epoch1, itr 8000] loss: 2.288
# [epoch1, itr10000] loss: 2.262
# [epoch1, itr12000] loss: 2.222
# Epoch=1 Test Accuracy=21.550
# [epoch2, itr 2000] loss: 2.158
# [epoch2, itr 4000] loss: 2.117
# [epoch2, itr 6000] loss: 2.077
# [epoch2, itr 8000] loss: 2.015
# [epoch2, itr10000] loss: 1.950
# [epoch2, itr12000] loss: 1.916
# Epoch=2 Test Accuracy=31.880
# [epoch3, itr 2000] loss: 1.887
# [epoch3, itr 4000] loss: 1.839
# [epoch3, itr 6000] loss: 1.824
# [epoch3, itr 8000] loss: 1.772
# [epoch3, itr10000] loss: 1.734
# [epoch3, itr12000] loss: 1.692
# Epoch=3 Test Accuracy=38.820
# [epoch4, itr 2000] loss: 1.662
# [epoch4, itr 4000] loss: 1.632
# [epoch4, itr 6000] loss: 1.596
# [epoch4, itr 8000] loss: 1.589
# [epoch4, itr10000] loss: 1.576
# [epoch4, itr12000] loss: 1.562
# Epoch=4 Test Accuracy=44.270
# [epoch5, itr 2000] loss: 1.530
# [epoch5, itr 4000] loss: 1.510
# [epoch5, itr 6000] loss: 1.500
# [epoch5, itr 8000] loss: 1.476
# [epoch5, itr10000] loss: 1.476
# [epoch5, itr12000] loss: 1.472
# Epoch=5 Test Accuracy=48.180
# [epoch6, itr 2000] loss: 1.434
# [epoch6, itr 4000] loss: 1.416
# [epoch6, itr 6000] loss: 1.414
# [epoch6, itr 8000] loss: 1.416
# [epoch6, itr10000] loss: 1.389
# [epoch6, itr12000] loss: 1.387
# Epoch=6 Test Accuracy=49.960
# [epoch7, itr 2000] loss: 1.362
# [epoch7, itr 4000] loss: 1.359
# [epoch7, itr 6000] loss: 1.347
# [epoch7, itr 8000] loss: 1.342
# [epoch7, itr10000] loss: 1.343
# [epoch7, itr12000] loss: 1.321
# Epoch=7 Test Accuracy=51.570
# [epoch8, itr 2000] loss: 1.324
# [epoch8, itr 4000] loss: 1.305
# [epoch8, itr 6000] loss: 1.282
# [epoch8, itr 8000] loss: 1.297
# [epoch8, itr10000] loss: 1.305
# [epoch8, itr12000] loss: 1.270
# Epoch=8 Test Accuracy=52.970
# [epoch9, itr 2000] loss: 1.255
# [epoch9, itr 4000] loss: 1.259
# [epoch9, itr 6000] loss: 1.246
# [epoch9, itr 8000] loss: 1.237
# [epoch9, itr10000] loss: 1.247
# [epoch9, itr12000] loss: 1.247
# Epoch=9 Test Accuracy=54.160
# [epoch10, itr 2000] loss: 1.209
# [epoch10, itr 4000] loss: 1.232
# [epoch10, itr 6000] loss: 1.188
# [epoch10, itr 8000] loss: 1.213
# [epoch10, itr10000] loss: 1.229
# [epoch10, itr12000] loss: 1.199
# Epoch=10 Test Accuracy=56.450
# Finished Training
# [epoch1, itr 2000] loss: 1.423
# [epoch1, itr 4000] loss: 1.391
# [epoch1, itr 6000] loss: 1.342
# [epoch1, itr 8000] loss: 1.324
# [epoch1, itr10000] loss: 1.317
# [epoch1, itr12000] loss: 1.283
# Epoch=1 Test Accuracy=53.850
# [epoch2, itr 2000] loss: 1.227
# [epoch2, itr 4000] loss: 1.230
# [epoch2, itr 6000] loss: 1.192
# [epoch2, itr 8000] loss: 1.201
# [epoch2, itr10000] loss: 1.192
# [epoch2, itr12000] loss: 1.159
# Epoch=2 Test Accuracy=58.710
# [epoch3, itr 2000] loss: 1.111
# [epoch3, itr 4000] loss: 1.120
# [epoch3, itr 6000] loss: 1.118
# [epoch3, itr 8000] loss: 1.129
# [epoch3, itr10000] loss: 1.113
# [epoch3, itr12000] loss: 1.101
# Epoch=3 Test Accuracy=58.910
# [epoch4, itr 2000] loss: 1.032
# [epoch4, itr 4000] loss: 1.049
# [epoch4, itr 6000] loss: 1.048
# [epoch4, itr 8000] loss: 1.050
# [epoch4, itr10000] loss: 1.047
# [epoch4, itr12000] loss: 1.049
# Epoch=4 Test Accuracy=58.820
# [epoch5, itr 2000] loss: 0.950
# [epoch5, itr 4000] loss: 0.990
# [epoch5, itr 6000] loss: 0.984
# [epoch5, itr 8000] loss: 0.979
# [epoch5, itr10000] loss: 1.013
# [epoch5, itr12000] loss: 1.021
# Epoch=5 Test Accuracy=60.740
# [epoch6, itr 2000] loss: 0.906
# [epoch6, itr 4000] loss: 0.937
# [epoch6, itr 6000] loss: 0.944
# [epoch6, itr 8000] loss: 1.004
# [epoch6, itr10000] loss: 0.975
# [epoch6, itr12000] loss: 0.948
# Epoch=6 Test Accuracy=60.720
# [epoch7, itr 2000] loss: 0.869
# [epoch7, itr 4000] loss: 0.875
# [epoch7, itr 6000] loss: 0.908
# [epoch7, itr 8000] loss: 0.903
# [epoch7, itr10000] loss: 0.928
# [epoch7, itr12000] loss: 0.963
# Epoch=7 Test Accuracy=61.620
# [epoch8, itr 2000] loss: 0.833
# [epoch8, itr 4000] loss: 0.856
# [epoch8, itr 6000] loss: 0.862
# [epoch8, itr 8000] loss: 0.889
# [epoch8, itr10000] loss: 0.880
# [epoch8, itr12000] loss: 0.909
# Epoch=8 Test Accuracy=60.560
# [epoch9, itr 2000] loss: 0.797
# [epoch9, itr 4000] loss: 0.822
# [epoch9, itr 6000] loss: 0.852
# [epoch9, itr 8000] loss: 0.858
# [epoch9, itr10000] loss: 0.858
# [epoch9, itr12000] loss: 0.885
# Epoch=9 Test Accuracy=60.460
# [epoch10, itr 2000] loss: 0.740
# [epoch10, itr 4000] loss: 0.791
# [epoch10, itr 6000] loss: 0.806
# [epoch10, itr 8000] loss: 0.831
# [epoch10, itr10000] loss: 0.857
# [epoch10, itr12000] loss: 0.859
# Epoch=10 Test Accuracy=60.970
# Finished Training
# [epoch1, itr 2000] loss: 2.080
# [epoch1, itr 4000] loss: 1.995
# [epoch1, itr 6000] loss: 2.001
# [epoch1, itr 8000] loss: 1.989
# [epoch1, itr10000] loss: 1.985
# [epoch1, itr12000] loss: 1.978
# Epoch=1 Test Accuracy=27.420
# [epoch2, itr 2000] loss: 1.984
# [epoch2, itr 4000] loss: 1.984
# [epoch2, itr 6000] loss: 1.956
# [epoch2, itr 8000] loss: 1.965
# [epoch2, itr10000] loss: 1.961
# [epoch2, itr12000] loss: 1.970
# Epoch=2 Test Accuracy=25.770
# [epoch3, itr 2000] loss: 1.959
# [epoch3, itr 4000] loss: 1.965
# [epoch3, itr 6000] loss: 1.995
# [epoch3, itr 8000] loss: 1.976
# [epoch3, itr10000] loss: 1.978
# [epoch3, itr12000] loss: 1.986
# Epoch=3 Test Accuracy=25.040
# [epoch4, itr 2000] loss: 1.983
# [epoch4, itr 4000] loss: 1.976
# [epoch4, itr 6000] loss: 1.941
# [epoch4, itr 8000] loss: 2.022
# [epoch4, itr10000] loss: 1.956
# [epoch4, itr12000] loss: 1.999
# Epoch=4 Test Accuracy=26.960
# [epoch5, itr 2000] loss: 1.978
# [epoch5, itr 4000] loss: 1.993
# [epoch5, itr 6000] loss: 1.999
# [epoch5, itr 8000] loss: 1.987
# [epoch5, itr10000] loss: 1.967
# [epoch5, itr12000] loss: 1.972
# Epoch=5 Test Accuracy=21.180
# [epoch6, itr 2000] loss: 2.010
# [epoch6, itr 4000] loss: 2.019
# [epoch6, itr 6000] loss: 1.980
# [epoch6, itr 8000] loss: 1.965
# [epoch6, itr10000] loss: 1.967
# [epoch6, itr12000] loss: 1.977
# Epoch=6 Test Accuracy=26.120
# [epoch7, itr 2000] loss: 1.958
# [epoch7, itr 4000] loss: 1.966
# [epoch7, itr 6000] loss: 1.987
# [epoch7, itr 8000] loss: 1.942
# [epoch7, itr10000] loss: 1.978
# [epoch7, itr12000] loss: 1.981
# Epoch=7 Test Accuracy=23.950
# [epoch8, itr 2000] loss: 1.970
# [epoch8, itr 4000] loss: 1.956
# [epoch8, itr 6000] loss: 1.961
# [epoch8, itr 8000] loss: 1.985
# [epoch8, itr10000] loss: 1.974
# [epoch8, itr12000] loss: 2.002
# Epoch=8 Test Accuracy=22.540
# [epoch9, itr 2000] loss: 1.987
# [epoch9, itr 4000] loss: 1.957
# [epoch9, itr 6000] loss: 1.964
# [epoch9, itr 8000] loss: 1.952
# [epoch9, itr10000] loss: 1.954
# [epoch9, itr12000] loss: 1.952
# Epoch=9 Test Accuracy=24.670
# [epoch10, itr 2000] loss: 1.960
# [epoch10, itr 4000] loss: 1.957
# [epoch10, itr 6000] loss: 1.956
# [epoch10, itr 8000] loss: 1.962
# [epoch10, itr10000] loss: 1.965
# [epoch10, itr12000] loss: 1.976
# Epoch=10 Test Accuracy=24.510
# Finished Training
# [epoch1, itr 2000] loss: 2.840
# [epoch1, itr 4000] loss: 2.359
# [epoch1, itr 6000] loss: 2.365
# [epoch1, itr 8000] loss: 2.356
# [epoch1, itr10000] loss: 2.356
# [epoch1, itr12000] loss: 2.361
# Epoch=1 Test Accuracy=10.000
# [epoch2, itr 2000] loss: 2.360
# [epoch2, itr 4000] loss: 2.361
# [epoch2, itr 6000] loss: 2.365
# [epoch2, itr 8000] loss: 2.366
# [epoch2, itr10000] loss: 2.362
# [epoch2, itr12000] loss: 2.359
# Epoch=2 Test Accuracy=10.000
# [epoch3, itr 2000] loss: 2.361
# [epoch3, itr 4000] loss: 2.362
# [epoch3, itr 6000] loss: 2.360
# [epoch3, itr 8000] loss: 2.358
# [epoch3, itr10000] loss: 2.360
# [epoch3, itr12000] loss: 2.361
# Epoch=3 Test Accuracy=10.000
# [epoch4, itr 2000] loss: 2.360
# [epoch4, itr 4000] loss: 2.359
# [epoch4, itr 6000] loss: 2.359
# [epoch4, itr 8000] loss: 2.357
# [epoch4, itr10000] loss: 2.357
# [epoch4, itr12000] loss: 2.359
# Epoch=4 Test Accuracy=10.000
# [epoch5, itr 2000] loss: 2.364
# [epoch5, itr 4000] loss: 2.362
# [epoch5, itr 6000] loss: 2.357
# [epoch5, itr 8000] loss: 2.356
# [epoch5, itr10000] loss: 2.358
# [epoch5, itr12000] loss: 2.356
# Epoch=5 Test Accuracy=10.000
# [epoch6, itr 2000] loss: 2.356
# [epoch6, itr 4000] loss: 2.360
# [epoch6, itr 6000] loss: 2.363
# [epoch6, itr 8000] loss: 2.359
# [epoch6, itr10000] loss: 2.364
# [epoch6, itr12000] loss: 2.360
# Epoch=6 Test Accuracy=10.000
# [epoch7, itr 2000] loss: 2.355
# [epoch7, itr 4000] loss: 2.360
# [epoch7, itr 6000] loss: 2.360
# [epoch7, itr 8000] loss: 2.358
# [epoch7, itr10000] loss: 2.361
# [epoch7, itr12000] loss: 2.361
# Epoch=7 Test Accuracy=10.000
# [epoch8, itr 2000] loss: 2.359
# [epoch8, itr 4000] loss: 2.359
# [epoch8, itr 6000] loss: 2.362
# [epoch8, itr 8000] loss: 2.360
# [epoch8, itr10000] loss: 2.361
# [epoch8, itr12000] loss: 2.358
# Epoch=8 Test Accuracy=10.000
# [epoch9, itr 2000] loss: 2.360
# [epoch9, itr 4000] loss: 2.364
# [epoch9, itr 6000] loss: 2.357
# [epoch9, itr 8000] loss: 2.361
# [epoch9, itr10000] loss: 2.361
# [epoch9, itr12000] loss: 2.359
# Epoch=9 Test Accuracy=10.000
# [epoch10, itr 2000] loss: 2.356
# [epoch10, itr 4000] loss: 2.363
# [epoch10, itr 6000] loss: 2.358
# [epoch10, itr 8000] loss: 2.362
# [epoch10, itr10000] loss: 2.366
# [epoch10, itr12000] loss: 2.356
# Epoch=10 Test Accuracy=10.000
# Finished Training

# %% [markdown]
# #Additional code to explore the dataset and the trained model

# %%
# Show some random training images

import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.size())
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# torch.Size([4, 3, 32, 32])
# truck  deer  ship plane

# %%
# Test the network on some test images

dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))

# The outputs are energies for the 10 classes.
# The higher the energy for a class, the more the network
# thinks that the image is of the particular class.
# So, let's get the index of the highest energy:
if CUDA:
  images = images.cuda()
  labels = labels.cuda()
else:
  images = images.cpu()
  labels =labels.cpu()
outputs = net(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:  truck truck truck truck

# %%
# Lets check what are the classes that performed well, and the classes that did
# not perform well:

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for images, labels in testloader:
        if CUDA:
          images =images.cuda()
          labels =labels.cuda()
        else:
          images =images.cpu()
          labels =labels.cpu()

        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane :  0 %
# Accuracy of   car :  0 %
# Accuracy of  bird :  0 %
# Accuracy of   cat :  0 %
# Accuracy of  deer :  0 %
# Accuracy of   dog :  0 %
# Accuracy of  frog :  0 %
# Accuracy of horse :  0 %
# Accuracy of  ship :  0 %
# Accuracy of truck : 100 %

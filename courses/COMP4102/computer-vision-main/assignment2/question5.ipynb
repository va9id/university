# %% [markdown]
# # Question 5

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
torch.cuda.is_available()

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the CNN Class
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # Step 1: Create the first convolutional layer (conv1)
        #   - Input channels: 3
        #   - Output channels: 6
        #   - Kernel size: 5
        self.conv1 = nn.Conv2d(3, 6, 5)

        # Step 2: Create max pooling layer (pool)
        #   - Kernel size: 2
        #   - Stride: 2
        self.pool = nn.MaxPool2d(2, 2)
        # Step 3: Create the second convolutional layer (conv2)
        #   - Input channels: 6
        #   - Output channels: 16
        #   - Kernel size: 5
        self.conv2 = nn.Conv2d(6, 16, 5)

        # Step 4: Create the first fully connected layer (fc1)
        #   - Input features: 16 * 5 * 5
        #   - Output features: 120
        self.fc1 = nn.Linear(16 * 5 * 5, 120)

        # Step 5: Create the second fully connected layer (fc2)
        #   - Input features: 120
        #   - Output features: 120
        self.fc2 = nn.Linear(120, 120)

        # Step 6: Create the third fully connected layer (fc3)
        #   - Input features: 120
        #   - Output features: 10 (number of classes in CIFAR-10)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        # Step 7: Define the forward pass
        #   - Apply conv1, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        #   - Apply conv2, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        #   - Reshape the tensor for the fully connected layers
        x = x.view(-1, 16 * 5 * 5)
        #   - Apply fc1, followed by ReLU activation
        x = F.relu(self.fc1(x))
        #   - Apply fc2, followed by ReLU activation
        x = F.relu(self.fc2(x))
        #   - Apply fc3 (output layer)
        x = self.fc3(x)
        #   - Return output
        return x 
print(Net())
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### 5 x 5 filter with Same Convolution

# %%
class NetSame5(nn.Module):
    def __init__(self):
        super(NetSame5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5, padding='same')
        self.fc1 = nn.Linear(16 * 8 * 8, 120)
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        # Step 7: Define the forward pass
        #   - Apply conv1, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        #   - Apply conv2, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        #   - Reshape the tensor for the fully connected layers
        x = x.view(-1, 16 * 8 * 8)
        #   - Apply fc1, followed by ReLU activation
        x = F.relu(self.fc1(x))
        #   - Apply fc2, followed by ReLU activation
        x = F.relu(self.fc2(x))
        #   - Apply fc3 (output layer)
        x = self.fc3(x)
        #   - Return output
        return x
print(NetSame5())
# Out:
# NetSame5(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (fc1): Linear(in_features=1024, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3 x 3 filter with Valid Convolution

# %%
class NetValid3(nn.Module):
    def __init__(self):
        super(NetValid3, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 3)  
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 3) 
        self.fc1 = nn.Linear(16 * 6 * 6, 120)
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 6 * 6)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

print(NetValid3())
# Out:
# NetValid3(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=576, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3 x 3 filter with Same Convolution

# %%
class NetSame3(nn.Module):
    def __init__(self):
        super(NetSame3, self).__init__()

        # 3x3 filters with same convolution
        self.conv1 = nn.Conv2d(3, 6, 3, padding=1)  # Same Convolution
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 3, padding=1)  # Same Convolution
        self.fc1 = nn.Linear(16 * 8 * 8, 120)  # Adjusted output size due to padding
        self.fc2 = nn.Linear(120, 120)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

print(NetSame3())
# Out:
# NetSame3(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
import torch.optim as optim
net=Net()
CUDA=torch.cuda.is_available()
if CUDA:
  net=net.cuda()

# Let's first define our device as the first visible cuda device if we have
# CUDA available:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)

#In Colab, got to Edit>Notebook settings> choose Python 3. For the hardware
#accelerator, you may select None or GPU.
# Out:
# cpu

# %%
# 4. Train the network
def network_training(net): 
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
  accuracy_values=[]
  epoch_number=[]
  for epoch in range(10):  # loop over the dataset multiple times. Here 10 means 10 epochs
      running_loss = 0.0
      for i, (inputs,labels) in enumerate(trainloader, 0):
          # get the inputs; data is a list of [inputs, labels]
          if CUDA:
            inputs = inputs.cuda()
            labels = labels.cuda()
          else:
            inputs = inputs.cpu()
            labels = labels.cpu()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 2000 == 1999:    # print every 2000 mini-batches
              print('[epoch%d, itr%5d] loss: %.3f' %
                    (epoch + 1, i + 1, running_loss / 2000))
              running_loss = 0.0

      correct = 0
      total = 0
      with torch.no_grad():
          for images, labels in testloader:
              if CUDA:
                images = images.cuda()
                labels = labels.cuda()
              else:
                images = images.cpu()
                labels =labels.cpu()

              outputs = net(images)
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              if CUDA:
                correct += (predicted.cpu()==labels.cpu()).sum().item()
              else:
                correct += (predicted==labels).sum().item()

          TestAccuracy = 100 * correct / total;
          epoch_number += [epoch+1]
          accuracy_values += [TestAccuracy]
          print('Epoch=%d Test Accuracy=%.3f' %
                    (epoch + 1, TestAccuracy))

  print('Finished Training')
  return accuracy_values, epoch_number

# %%
import matplotlib.pyplot as plt
import numpy as np

nets = [Net(), NetValid3(), NetSame5(), NetSame3()]
names = ["5x5 valid", "3x3 valid", "5x5 same", "3x3 same"]
colors = ["blue", "red", "black", "yellow"]

for net, name, color in zip(nets, names, colors):
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
    accuracy_values, epoch_number = network_training(net)
    # Plot the data
    plt.plot(epoch_number, accuracy_values, color=color, label=name)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

# Add a legend
plt.legend()

# Show the plot
plt.show()

## Anything better than 10% accuracy (randomly picking a class out of 10 classes)
# means the network has learned something.
# Out:
# [epoch1, itr 2000] loss: 2.174
# [epoch1, itr 4000] loss: 1.860
# [epoch1, itr 6000] loss: 1.655
# [epoch1, itr 8000] loss: 1.589
# [epoch1, itr10000] loss: 1.526
# [epoch1, itr12000] loss: 1.475
# Epoch=1 Test Accuracy=48.630
# [epoch2, itr 2000] loss: 1.414
# [epoch2, itr 4000] loss: 1.380
# [epoch2, itr 6000] loss: 1.356
# [epoch2, itr 8000] loss: 1.329
# [epoch2, itr10000] loss: 1.319
# [epoch2, itr12000] loss: 1.274
# Epoch=2 Test Accuracy=54.360
# [epoch3, itr 2000] loss: 1.241
# [epoch3, itr 4000] loss: 1.206
# [epoch3, itr 6000] loss: 1.187
# [epoch3, itr 8000] loss: 1.227
# [epoch3, itr10000] loss: 1.202
# [epoch3, itr12000] loss: 1.162
# Epoch=3 Test Accuracy=58.700
# [epoch4, itr 2000] loss: 1.105
# [epoch4, itr 4000] loss: 1.105
# [epoch4, itr 6000] loss: 1.132
# [epoch4, itr 8000] loss: 1.109
# [epoch4, itr10000] loss: 1.116
# [epoch4, itr12000] loss: 1.125
# Epoch=4 Test Accuracy=59.180
# [epoch5, itr 2000] loss: 1.043
# [epoch5, itr 4000] loss: 1.048
# [epoch5, itr 6000] loss: 1.052
# [epoch5, itr 8000] loss: 1.040
# [epoch5, itr10000] loss: 1.040
# [epoch5, itr12000] loss: 1.042
# Epoch=5 Test Accuracy=60.140
# [epoch6, itr 2000] loss: 0.966
# [epoch6, itr 4000] loss: 0.979
# [epoch6, itr 6000] loss: 0.975
# [epoch6, itr 8000] loss: 0.983
# [epoch6, itr10000] loss: 1.007
# [epoch6, itr12000] loss: 1.002
# Epoch=6 Test Accuracy=61.570
# [epoch7, itr 2000] loss: 0.909
# [epoch7, itr 4000] loss: 0.945
# [epoch7, itr 6000] loss: 0.949
# [epoch7, itr 8000] loss: 0.942
# [epoch7, itr10000] loss: 0.949
# [epoch7, itr12000] loss: 0.950
# Epoch=7 Test Accuracy=60.550
# [epoch8, itr 2000] loss: 0.848
# [epoch8, itr 4000] loss: 0.886
# [epoch8, itr 6000] loss: 0.908
# [epoch8, itr 8000] loss: 0.917
# [epoch8, itr10000] loss: 0.917
# [epoch8, itr12000] loss: 0.924
# Epoch=8 Test Accuracy=63.100
# [epoch9, itr 2000] loss: 0.826
# [epoch9, itr 4000] loss: 0.838
# [epoch9, itr 6000] loss: 0.869
# [epoch9, itr 8000] loss: 0.879
# [epoch9, itr10000] loss: 0.887
# [epoch9, itr12000] loss: 0.908
# Epoch=9 Test Accuracy=60.970
# [epoch10, itr 2000] loss: 0.786
# [epoch10, itr 4000] loss: 0.816
# [epoch10, itr 6000] loss: 0.826
# [epoch10, itr 8000] loss: 0.842
# [epoch10, itr10000] loss: 0.858
# [epoch10, itr12000] loss: 0.858
# Epoch=10 Test Accuracy=60.520
# Finished Training
# [epoch1, itr 2000] loss: 2.221
# [epoch1, itr 4000] loss: 1.955
# [epoch1, itr 6000] loss: 1.770
# [epoch1, itr 8000] loss: 1.617
# [epoch1, itr10000] loss: 1.558
# [epoch1, itr12000] loss: 1.468
# Epoch=1 Test Accuracy=48.350
# [epoch2, itr 2000] loss: 1.415
# [epoch2, itr 4000] loss: 1.377
# [epoch2, itr 6000] loss: 1.348
# [epoch2, itr 8000] loss: 1.322
# [epoch2, itr10000] loss: 1.293
# [epoch2, itr12000] loss: 1.283
# Epoch=2 Test Accuracy=56.330
# [epoch3, itr 2000] loss: 1.208
# [epoch3, itr 4000] loss: 1.191
# [epoch3, itr 6000] loss: 1.192
# [epoch3, itr 8000] loss: 1.180
# [epoch3, itr10000] loss: 1.165
# [epoch3, itr12000] loss: 1.169
# Epoch=3 Test Accuracy=56.890
# [epoch4, itr 2000] loss: 1.077
# [epoch4, itr 4000] loss: 1.091
# [epoch4, itr 6000] loss: 1.071
# [epoch4, itr 8000] loss: 1.081
# [epoch4, itr10000] loss: 1.069
# [epoch4, itr12000] loss: 1.072
# Epoch=4 Test Accuracy=59.940
# [epoch5, itr 2000] loss: 0.993
# [epoch5, itr 4000] loss: 0.973
# [epoch5, itr 6000] loss: 0.980
# [epoch5, itr 8000] loss: 0.990
# [epoch5, itr10000] loss: 1.012
# [epoch5, itr12000] loss: 0.974
# Epoch=5 Test Accuracy=61.200
# [epoch6, itr 2000] loss: 0.887
# [epoch6, itr 4000] loss: 0.905
# [epoch6, itr 6000] loss: 0.916
# [epoch6, itr 8000] loss: 0.918
# [epoch6, itr10000] loss: 0.938
# [epoch6, itr12000] loss: 0.927
# Epoch=6 Test Accuracy=63.230
# [epoch7, itr 2000] loss: 0.820
# [epoch7, itr 4000] loss: 0.838
# [epoch7, itr 6000] loss: 0.870
# [epoch7, itr 8000] loss: 0.862
# [epoch7, itr10000] loss: 0.883
# [epoch7, itr12000] loss: 0.871
# Epoch=7 Test Accuracy=62.820
# [epoch8, itr 2000] loss: 0.762
# [epoch8, itr 4000] loss: 0.770
# [epoch8, itr 6000] loss: 0.805
# [epoch8, itr 8000] loss: 0.819
# [epoch8, itr10000] loss: 0.806
# [epoch8, itr12000] loss: 0.831
# Epoch=8 Test Accuracy=62.470
# [epoch9, itr 2000] loss: 0.690
# [epoch9, itr 4000] loss: 0.731
# [epoch9, itr 6000] loss: 0.737
# [epoch9, itr 8000] loss: 0.773
# [epoch9, itr10000] loss: 0.775
# [epoch9, itr12000] loss: 0.790
# Epoch=9 Test Accuracy=62.760
# [epoch10, itr 2000] loss: 0.640
# [epoch10, itr 4000] loss: 0.684
# [epoch10, itr 6000] loss: 0.720
# [epoch10, itr 8000] loss: 0.703
# [epoch10, itr10000] loss: 0.722
# [epoch10, itr12000] loss: 0.757
# Epoch=10 Test Accuracy=62.230
# Finished Training
# [epoch1, itr 2000] loss: 2.125
# [epoch1, itr 4000] loss: 1.759
# [epoch1, itr 6000] loss: 1.593
# [epoch1, itr 8000] loss: 1.482
# [epoch1, itr10000] loss: 1.432
# [epoch1, itr12000] loss: 1.355
# Epoch=1 Test Accuracy=52.330
# [epoch2, itr 2000] loss: 1.265
# [epoch2, itr 4000] loss: 1.231
# [epoch2, itr 6000] loss: 1.190
# [epoch2, itr 8000] loss: 1.200
# [epoch2, itr10000] loss: 1.166
# [epoch2, itr12000] loss: 1.145
# Epoch=2 Test Accuracy=58.630
# [epoch3, itr 2000] loss: 1.034
# [epoch3, itr 4000] loss: 1.058
# [epoch3, itr 6000] loss: 1.044
# [epoch3, itr 8000] loss: 1.042
# [epoch3, itr10000] loss: 1.011
# [epoch3, itr12000] loss: 1.011
# Epoch=3 Test Accuracy=61.920
# [epoch4, itr 2000] loss: 0.883
# [epoch4, itr 4000] loss: 0.941
# [epoch4, itr 6000] loss: 0.923
# [epoch4, itr 8000] loss: 0.931
# [epoch4, itr10000] loss: 0.946
# [epoch4, itr12000] loss: 0.916
# Epoch=4 Test Accuracy=64.990
# [epoch5, itr 2000] loss: 0.825
# [epoch5, itr 4000] loss: 0.814
# [epoch5, itr 6000] loss: 0.864
# [epoch5, itr 8000] loss: 0.853
# [epoch5, itr10000] loss: 0.847
# [epoch5, itr12000] loss: 0.833
# Epoch=5 Test Accuracy=66.000
# [epoch6, itr 2000] loss: 0.714
# [epoch6, itr 4000] loss: 0.749
# [epoch6, itr 6000] loss: 0.743
# [epoch6, itr 8000] loss: 0.782
# [epoch6, itr10000] loss: 0.787
# [epoch6, itr12000] loss: 0.805
# Epoch=6 Test Accuracy=63.960
# [epoch7, itr 2000] loss: 0.650
# [epoch7, itr 4000] loss: 0.675
# [epoch7, itr 6000] loss: 0.698
# [epoch7, itr 8000] loss: 0.712
# [epoch7, itr10000] loss: 0.718
# [epoch7, itr12000] loss: 0.753
# Epoch=7 Test Accuracy=64.630
# [epoch8, itr 2000] loss: 0.578
# [epoch8, itr 4000] loss: 0.610
# [epoch8, itr 6000] loss: 0.635
# [epoch8, itr 8000] loss: 0.656
# [epoch8, itr10000] loss: 0.679
# [epoch8, itr12000] loss: 0.690
# Epoch=8 Test Accuracy=65.610
# [epoch9, itr 2000] loss: 0.516
# [epoch9, itr 4000] loss: 0.555
# [epoch9, itr 6000] loss: 0.606
# [epoch9, itr 8000] loss: 0.595
# [epoch9, itr10000] loss: 0.627
# [epoch9, itr12000] loss: 0.645
# Epoch=9 Test Accuracy=64.200
# [epoch10, itr 2000] loss: 0.481
# [epoch10, itr 4000] loss: 0.501
# [epoch10, itr 6000] loss: 0.540
# [epoch10, itr 8000] loss: 0.571
# [epoch10, itr10000] loss: 0.596
# [epoch10, itr12000] loss: 0.574
# Epoch=10 Test Accuracy=64.760
# Finished Training
# [epoch1, itr 2000] loss: 2.217
# [epoch1, itr 4000] loss: 1.870
# [epoch1, itr 6000] loss: 1.627
# [epoch1, itr 8000] loss: 1.512
# [epoch1, itr10000] loss: 1.437
# [epoch1, itr12000] loss: 1.402
# Epoch=1 Test Accuracy=52.710
# [epoch2, itr 2000] loss: 1.297
# [epoch2, itr 4000] loss: 1.279
# [epoch2, itr 6000] loss: 1.255
# [epoch2, itr 8000] loss: 1.199
# [epoch2, itr10000] loss: 1.197
# [epoch2, itr12000] loss: 1.168
# Epoch=2 Test Accuracy=54.780
# [epoch3, itr 2000] loss: 1.099
# [epoch3, itr 4000] loss: 1.089
# [epoch3, itr 6000] loss: 1.069
# [epoch3, itr 8000] loss: 1.055
# [epoch3, itr10000] loss: 1.065
# [epoch3, itr12000] loss: 1.050
# Epoch=3 Test Accuracy=59.520
# [epoch4, itr 2000] loss: 0.960
# [epoch4, itr 4000] loss: 0.964
# [epoch4, itr 6000] loss: 0.952
# [epoch4, itr 8000] loss: 0.966
# [epoch4, itr10000] loss: 0.953
# [epoch4, itr12000] loss: 0.986
# Epoch=4 Test Accuracy=62.620
# [epoch5, itr 2000] loss: 0.833
# [epoch5, itr 4000] loss: 0.865
# [epoch5, itr 6000] loss: 0.881
# [epoch5, itr 8000] loss: 0.882
# [epoch5, itr10000] loss: 0.901
# [epoch5, itr12000] loss: 0.885
# Epoch=5 Test Accuracy=61.730
# [epoch6, itr 2000] loss: 0.789
# [epoch6, itr 4000] loss: 0.784
# [epoch6, itr 6000] loss: 0.832
# [epoch6, itr 8000] loss: 0.788
# [epoch6, itr10000] loss: 0.807
# [epoch6, itr12000] loss: 0.805
# Epoch=6 Test Accuracy=64.890
# [epoch7, itr 2000] loss: 0.658
# [epoch7, itr 4000] loss: 0.723
# [epoch7, itr 6000] loss: 0.741
# [epoch7, itr 8000] loss: 0.740
# [epoch7, itr10000] loss: 0.762
# [epoch7, itr12000] loss: 0.759
# Epoch=7 Test Accuracy=64.660
# [epoch8, itr 2000] loss: 0.598
# [epoch8, itr 4000] loss: 0.648
# [epoch8, itr 6000] loss: 0.670
# [epoch8, itr 8000] loss: 0.688
# [epoch8, itr10000] loss: 0.694
# [epoch8, itr12000] loss: 0.715
# Epoch=8 Test Accuracy=64.760
# [epoch9, itr 2000] loss: 0.536
# [epoch9, itr 4000] loss: 0.604
# [epoch9, itr 6000] loss: 0.615
# [epoch9, itr 8000] loss: 0.635
# [epoch9, itr10000] loss: 0.672
# [epoch9, itr12000] loss: 0.648
# Epoch=9 Test Accuracy=62.360
# [epoch10, itr 2000] loss: 0.495
# [epoch10, itr 4000] loss: 0.537
# [epoch10, itr 6000] loss: 0.544
# [epoch10, itr 8000] loss: 0.581
# [epoch10, itr10000] loss: 0.610
# [epoch10, itr12000] loss: 0.619
# Epoch=10 Test Accuracy=63.300
# Finished Training

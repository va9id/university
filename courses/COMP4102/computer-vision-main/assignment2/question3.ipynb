# %% [markdown]
# # Question 3

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
torch.cuda.is_available()

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# 0.0%
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the CNN Class
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # Step 1: Create the first convolutional layer (conv1)
        #   - Input channels: 3
        #   - Output channels: 6
        #   - Kernel size: 5
        self.conv1 = nn.Conv2d(3, 6, 5)

        # Step 2: Create max pooling layer (pool)
        #   - Kernel size: 2
        #   - Stride: 2
        self.pool = nn.MaxPool2d(2, 2)
        # Step 3: Create the second convolutional layer (conv2)
        #   - Input channels: 6
        #   - Output channels: 16
        #   - Kernel size: 5
        self.conv2 = nn.Conv2d(6, 16, 5)

        # Step 4: Create the first fully connected layer (fc1)
        #   - Input features: 16 * 5 * 5
        #   - Output features: 120
        self.fc1 = nn.Linear(16 * 5 * 5, 120)

        # Step 5: Create the second fully connected layer (fc2)
        #   - Input features: 120
        #   - Output features: 120
        self.fc2 = nn.Linear(120, 120)

        # Step 6: Create the third fully connected layer (fc3)
        #   - Input features: 120
        #   - Output features: 10 (number of classes in CIFAR-10)
        self.fc3 = nn.Linear(120, 10)

    def forward(self, x):
        # Step 7: Define the forward pass
        #   - Apply conv1, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        #   - Apply conv2, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv2(x)))
        #   - Reshape the tensor for the fully connected layers
        x = x.view(-1, 16 * 5 * 5)
        #   - Apply fc1, followed by ReLU activation
        x = F.relu(self.fc1(x))
        #   - Apply fc2, followed by ReLU activation
        x = F.relu(self.fc2(x))
        #   - Apply fc3 (output layer)
        x = self.fc3(x)
        #   - Return output
        return x 
print(Net())
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
import torch.optim as optim
net=Net()
CUDA=torch.cuda.is_available()
if CUDA:
  net=net.cuda()

# Let's first define our device as the first visible cuda device if we have
# CUDA available:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)

#In Colab, got to Edit>Notebook settings> choose Python 3. For the hardware
#accelerator, you may select None or GPU.
# Out:
# cpu

# %%
# 4. Train the network
def network_training(): 
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
  accuracy_values=[]
  epoch_number=[]
  for epoch in range(10):  # loop over the dataset multiple times. Here 10 means 10 epochs
      running_loss = 0.0
      for i, (inputs,labels) in enumerate(trainloader, 0):
          # get the inputs; data is a list of [inputs, labels]
          if CUDA:
            inputs = inputs.cuda()
            labels = labels.cuda()
          else:
            inputs = inputs.cpu()
            labels = labels.cpu()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 2000 == 1999:    # print every 2000 mini-batches
              print('[epoch%d, itr%5d] loss: %.3f' %
                    (epoch + 1, i + 1, running_loss / 2000))
              running_loss = 0.0

      correct = 0
      total = 0
      with torch.no_grad():
          for images, labels in testloader:
              if CUDA:
                images = images.cuda()
                labels = labels.cuda()
              else:
                images = images.cpu()
                labels =labels.cpu()

              outputs = net(images)
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              if CUDA:
                correct += (predicted.cpu()==labels.cpu()).sum().item()
              else:
                correct += (predicted==labels).sum().item()

          TestAccuracy = 100 * correct / total;
          epoch_number += [epoch+1]
          accuracy_values += [TestAccuracy]
          print('Epoch=%d Test Accuracy=%.3f' %
                    (epoch + 1, TestAccuracy))

  print('Finished Training')
  return accuracy_values, epoch_number

# %%
import matplotlib.pyplot as plt
import numpy as np

batch_sizes = [1, 4, 16, 64, 256]
names = ["size=1", "size=4", "size=16", "size=64", "size=256"]
colors = ["blue", "red", "green", "yellow", "black"]

for batch_size, name, color in zip(batch_sizes, names, colors):
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
    accuracy_values, epoch_number = network_training()
    # Plot the data
    plt.plot(epoch_number, accuracy_values, color=color, label=name)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

# Add a legend
plt.legend()

# Show the plot
plt.show()

## Anything better than 10% accuracy (randomly picking a class out of 10 classes)
# means the network has learned something.
# Out:
# [epoch1, itr 2000] loss: 2.208
# [epoch1, itr 4000] loss: 1.974
# [epoch1, itr 6000] loss: 1.870
# [epoch1, itr 8000] loss: 1.830
# [epoch1, itr10000] loss: 1.774
# [epoch1, itr12000] loss: 1.749
# [epoch1, itr14000] loss: 1.692
# [epoch1, itr16000] loss: 1.674
# [epoch1, itr18000] loss: 1.658
# [epoch1, itr20000] loss: 1.631
# [epoch1, itr22000] loss: 1.630
# [epoch1, itr24000] loss: 1.610
# [epoch1, itr26000] loss: 1.641
# [epoch1, itr28000] loss: 1.598
# [epoch1, itr30000] loss: 1.572
# [epoch1, itr32000] loss: 1.562
# [epoch1, itr34000] loss: 1.573
# [epoch1, itr36000] loss: 1.557
# [epoch1, itr38000] loss: 1.527
# [epoch1, itr40000] loss: 1.532
# [epoch1, itr42000] loss: 1.550
# [epoch1, itr44000] loss: 1.521
# [epoch1, itr46000] loss: 1.526
# [epoch1, itr48000] loss: 1.524
# [epoch1, itr50000] loss: 1.516
# Epoch=1 Test Accuracy=42.040
# [epoch2, itr 2000] loss: 1.474
# [epoch2, itr 4000] loss: 1.508
# [epoch2, itr 6000] loss: 1.527
# [epoch2, itr 8000] loss: 1.455
# [epoch2, itr10000] loss: 1.454
# [epoch2, itr12000] loss: 1.467
# [epoch2, itr14000] loss: 1.458
# [epoch2, itr16000] loss: 1.437
# [epoch2, itr18000] loss: 1.479
# [epoch2, itr20000] loss: 1.510
# [epoch2, itr22000] loss: 1.473
# [epoch2, itr24000] loss: 1.523
# [epoch2, itr26000] loss: 1.506
# [epoch2, itr28000] loss: 1.464
# [epoch2, itr30000] loss: 1.497
# [epoch2, itr32000] loss: 1.488
# [epoch2, itr34000] loss: 1.502
# [epoch2, itr36000] loss: 1.513
# [epoch2, itr38000] loss: 1.477
# [epoch2, itr40000] loss: 1.490
# [epoch2, itr42000] loss: 1.486
# [epoch2, itr44000] loss: 1.438
# [epoch2, itr46000] loss: 1.513
# [epoch2, itr48000] loss: 1.417
# [epoch2, itr50000] loss: 1.478
# Epoch=2 Test Accuracy=48.570
# [epoch3, itr 2000] loss: 1.390
# [epoch3, itr 4000] loss: 1.424
# [epoch3, itr 6000] loss: 1.402
# [epoch3, itr 8000] loss: 1.440
# [epoch3, itr10000] loss: 1.388
# [epoch3, itr12000] loss: 1.479
# [epoch3, itr14000] loss: 1.442
# [epoch3, itr16000] loss: 1.490
# [epoch3, itr18000] loss: 1.455
# [epoch3, itr20000] loss: 1.481
# [epoch3, itr22000] loss: 1.453
# [epoch3, itr24000] loss: 1.473
# [epoch3, itr26000] loss: 1.417
# [epoch3, itr28000] loss: 1.452
# [epoch3, itr30000] loss: 1.512
# [epoch3, itr32000] loss: 1.454
# [epoch3, itr34000] loss: 1.509
# [epoch3, itr36000] loss: 1.430
# [epoch3, itr38000] loss: 1.436
# [epoch3, itr40000] loss: 1.434
# [epoch3, itr42000] loss: 1.424
# [epoch3, itr44000] loss: 1.447
# [epoch3, itr46000] loss: 1.439
# [epoch3, itr48000] loss: 1.443
# [epoch3, itr50000] loss: 1.514
# Epoch=3 Test Accuracy=46.950
# [epoch4, itr 2000] loss: 1.379
# [epoch4, itr 4000] loss: 1.373
# [epoch4, itr 6000] loss: 1.409
# [epoch4, itr 8000] loss: 1.418
# [epoch4, itr10000] loss: 1.458
# [epoch4, itr12000] loss: 1.446
# [epoch4, itr14000] loss: 1.456
# [epoch4, itr16000] loss: 1.446
# [epoch4, itr18000] loss: 1.489
# [epoch4, itr20000] loss: 1.416
# [epoch4, itr22000] loss: 1.489
# [epoch4, itr24000] loss: 1.507
# [epoch4, itr26000] loss: 1.460
# [epoch4, itr28000] loss: 1.430
# [epoch4, itr30000] loss: 1.482
# [epoch4, itr32000] loss: 1.473
# [epoch4, itr34000] loss: 1.483
# [epoch4, itr36000] loss: 1.464
# [epoch4, itr38000] loss: 1.497
# [epoch4, itr40000] loss: 1.453
# [epoch4, itr42000] loss: 1.435
# [epoch4, itr44000] loss: 1.463
# [epoch4, itr46000] loss: 1.430
# [epoch4, itr48000] loss: 1.459
# [epoch4, itr50000] loss: 1.506
# Epoch=4 Test Accuracy=45.700
# [epoch5, itr 2000] loss: 1.465
# [epoch5, itr 4000] loss: 1.450
# [epoch5, itr 6000] loss: 1.429
# [epoch5, itr 8000] loss: 1.412
# [epoch5, itr10000] loss: 1.381
# [epoch5, itr12000] loss: 1.464
# [epoch5, itr14000] loss: 1.404
# [epoch5, itr16000] loss: 1.465
# [epoch5, itr18000] loss: 1.431
# [epoch5, itr20000] loss: 1.491
# [epoch5, itr22000] loss: 1.475
# [epoch5, itr24000] loss: 1.418
# [epoch5, itr26000] loss: 1.459
# [epoch5, itr28000] loss: 1.443
# [epoch5, itr30000] loss: 1.481
# [epoch5, itr32000] loss: 1.456
# [epoch5, itr34000] loss: 1.384
# [epoch5, itr36000] loss: 1.433
# [epoch5, itr38000] loss: 1.475
# [epoch5, itr40000] loss: 1.436
# [epoch5, itr42000] loss: 1.482
# [epoch5, itr44000] loss: 1.511
# [epoch5, itr46000] loss: 1.449
# [epoch5, itr48000] loss: 1.486
# [epoch5, itr50000] loss: 1.512
# Epoch=5 Test Accuracy=46.090
# [epoch6, itr 2000] loss: 1.403
# [epoch6, itr 4000] loss: 1.412
# [epoch6, itr 6000] loss: 1.416
# [epoch6, itr 8000] loss: 1.432
# [epoch6, itr10000] loss: 1.395
# [epoch6, itr12000] loss: 1.440
# [epoch6, itr14000] loss: 1.423
# [epoch6, itr16000] loss: 1.446
# [epoch6, itr18000] loss: 1.435
# [epoch6, itr20000] loss: 1.468
# [epoch6, itr22000] loss: 1.528
# [epoch6, itr24000] loss: 1.478
# [epoch6, itr26000] loss: 1.431
# [epoch6, itr28000] loss: 1.409
# [epoch6, itr30000] loss: 1.474
# [epoch6, itr32000] loss: 1.420
# [epoch6, itr34000] loss: 1.483
# [epoch6, itr36000] loss: 1.494
# [epoch6, itr38000] loss: 1.489
# [epoch6, itr40000] loss: 1.460
# [epoch6, itr42000] loss: 1.503
# [epoch6, itr44000] loss: 1.453
# [epoch6, itr46000] loss: 1.458
# [epoch6, itr48000] loss: 1.500
# [epoch6, itr50000] loss: 1.538
# Epoch=6 Test Accuracy=46.820
# [epoch7, itr 2000] loss: 1.357
# [epoch7, itr 4000] loss: 1.432
# [epoch7, itr 6000] loss: 1.405
# [epoch7, itr 8000] loss: 1.451
# [epoch7, itr10000] loss: 1.454
# [epoch7, itr12000] loss: 1.480
# [epoch7, itr14000] loss: 1.384
# [epoch7, itr16000] loss: 1.436
# [epoch7, itr18000] loss: 1.421
# [epoch7, itr20000] loss: 1.434
# [epoch7, itr22000] loss: 1.475
# [epoch7, itr24000] loss: 1.438
# [epoch7, itr26000] loss: 1.408
# [epoch7, itr28000] loss: 1.522
# [epoch7, itr30000] loss: 1.495
# [epoch7, itr32000] loss: 1.429
# [epoch7, itr34000] loss: 1.470
# [epoch7, itr36000] loss: 1.476
# [epoch7, itr38000] loss: 1.482
# [epoch7, itr40000] loss: 1.478
# [epoch7, itr42000] loss: 1.490
# [epoch7, itr44000] loss: 1.481
# [epoch7, itr46000] loss: 1.477
# [epoch7, itr48000] loss: 1.474
# [epoch7, itr50000] loss: 1.443
# Epoch=7 Test Accuracy=48.250
# [epoch8, itr 2000] loss: 1.402
# [epoch8, itr 4000] loss: 1.464
# [epoch8, itr 6000] loss: 1.453
# [epoch8, itr 8000] loss: 1.441
# [epoch8, itr10000] loss: 1.445
# [epoch8, itr12000] loss: 1.418
# [epoch8, itr14000] loss: 1.475
# [epoch8, itr16000] loss: 1.441
# [epoch8, itr18000] loss: 1.456
# [epoch8, itr20000] loss: 1.421
# [epoch8, itr22000] loss: 1.441
# [epoch8, itr24000] loss: 1.500
# [epoch8, itr26000] loss: 1.452
# [epoch8, itr28000] loss: 1.440
# [epoch8, itr30000] loss: 1.536
# [epoch8, itr32000] loss: 1.460
# [epoch8, itr34000] loss: 1.434
# [epoch8, itr36000] loss: 1.457
# [epoch8, itr38000] loss: 1.463
# [epoch8, itr40000] loss: 1.494
# [epoch8, itr42000] loss: 1.570
# [epoch8, itr44000] loss: 1.510
# [epoch8, itr46000] loss: 1.459
# [epoch8, itr48000] loss: 1.500
# [epoch8, itr50000] loss: 1.489
# Epoch=8 Test Accuracy=47.220
# [epoch9, itr 2000] loss: 1.438
# [epoch9, itr 4000] loss: 1.375
# [epoch9, itr 6000] loss: 1.396
# [epoch9, itr 8000] loss: 1.459
# [epoch9, itr10000] loss: 1.427
# [epoch9, itr12000] loss: 1.469
# [epoch9, itr14000] loss: 1.426
# [epoch9, itr16000] loss: 1.464
# [epoch9, itr18000] loss: 1.434
# [epoch9, itr20000] loss: 1.458
# [epoch9, itr22000] loss: 1.463
# [epoch9, itr24000] loss: 1.488
# [epoch9, itr26000] loss: 1.436
# [epoch9, itr28000] loss: 1.467
# [epoch9, itr30000] loss: 1.435
# [epoch9, itr32000] loss: 1.444
# [epoch9, itr34000] loss: 1.413
# [epoch9, itr36000] loss: 1.470
# [epoch9, itr38000] loss: 1.546
# [epoch9, itr40000] loss: 1.468
# [epoch9, itr42000] loss: 1.526
# [epoch9, itr44000] loss: 1.467
# [epoch9, itr46000] loss: 1.558
# [epoch9, itr48000] loss: 1.513
# [epoch9, itr50000] loss: 1.519
# Epoch=9 Test Accuracy=48.560
# [epoch10, itr 2000] loss: 1.431
# [epoch10, itr 4000] loss: 1.425
# [epoch10, itr 6000] loss: 1.431
# [epoch10, itr 8000] loss: 1.482
# [epoch10, itr10000] loss: 1.460
# [epoch10, itr12000] loss: 1.428
# [epoch10, itr14000] loss: 1.412
# [epoch10, itr16000] loss: 1.361
# [epoch10, itr18000] loss: 1.499
# [epoch10, itr20000] loss: 1.449
# [epoch10, itr22000] loss: 1.495
# [epoch10, itr24000] loss: 1.470
# [epoch10, itr26000] loss: 1.488
# [epoch10, itr28000] loss: 1.446
# [epoch10, itr30000] loss: 1.473
# [epoch10, itr32000] loss: 1.443
# [epoch10, itr34000] loss: 1.409
# [epoch10, itr36000] loss: 1.495
# [epoch10, itr38000] loss: 1.463
# [epoch10, itr40000] loss: 1.478
# [epoch10, itr42000] loss: 1.480
# [epoch10, itr44000] loss: 1.499
# [epoch10, itr46000] loss: 1.521
# [epoch10, itr48000] loss: 1.549
# [epoch10, itr50000] loss: 1.520
# Epoch=10 Test Accuracy=47.090
# Finished Training
# [epoch1, itr 2000] loss: 1.241
# [epoch1, itr 4000] loss: 1.182
# [epoch1, itr 6000] loss: 1.133
# [epoch1, itr 8000] loss: 1.133
# [epoch1, itr10000] loss: 1.100
# [epoch1, itr12000] loss: 1.112
# Epoch=1 Test Accuracy=57.470
# [epoch2, itr 2000] loss: 1.008
# [epoch2, itr 4000] loss: 1.043
# [epoch2, itr 6000] loss: 1.056
# [epoch2, itr 8000] loss: 1.031
# [epoch2, itr10000] loss: 1.031
# [epoch2, itr12000] loss: 1.055
# Epoch=2 Test Accuracy=57.840
# [epoch3, itr 2000] loss: 0.941
# [epoch3, itr 4000] loss: 0.976
# [epoch3, itr 6000] loss: 0.972
# [epoch3, itr 8000] loss: 0.994
# [epoch3, itr10000] loss: 0.983
# [epoch3, itr12000] loss: 0.996
# Epoch=3 Test Accuracy=59.570
# [epoch4, itr 2000] loss: 0.908
# [epoch4, itr 4000] loss: 0.918
# [epoch4, itr 6000] loss: 0.924
# [epoch4, itr 8000] loss: 0.961
# [epoch4, itr10000] loss: 0.945
# [epoch4, itr12000] loss: 0.928
# Epoch=4 Test Accuracy=59.350
# [epoch5, itr 2000] loss: 0.852
# [epoch5, itr 4000] loss: 0.885
# [epoch5, itr 6000] loss: 0.888
# [epoch5, itr 8000] loss: 0.881
# [epoch5, itr10000] loss: 0.920
# [epoch5, itr12000] loss: 0.924
# Epoch=5 Test Accuracy=59.070
# [epoch6, itr 2000] loss: 0.823
# [epoch6, itr 4000] loss: 0.847
# [epoch6, itr 6000] loss: 0.875
# [epoch6, itr 8000] loss: 0.862
# [epoch6, itr10000] loss: 0.885
# [epoch6, itr12000] loss: 0.866
# Epoch=6 Test Accuracy=59.590
# [epoch7, itr 2000] loss: 0.795
# [epoch7, itr 4000] loss: 0.818
# [epoch7, itr 6000] loss: 0.822
# [epoch7, itr 8000] loss: 0.848
# [epoch7, itr10000] loss: 0.830
# [epoch7, itr12000] loss: 0.861
# Epoch=7 Test Accuracy=59.400
# [epoch8, itr 2000] loss: 0.774
# [epoch8, itr 4000] loss: 0.800
# [epoch8, itr 6000] loss: 0.788
# [epoch8, itr 8000] loss: 0.796
# [epoch8, itr10000] loss: 0.816
# [epoch8, itr12000] loss: 0.822
# Epoch=8 Test Accuracy=59.680
# [epoch9, itr 2000] loss: 0.741
# [epoch9, itr 4000] loss: 0.767
# [epoch9, itr 6000] loss: 0.790
# [epoch9, itr 8000] loss: 0.790
# [epoch9, itr10000] loss: 0.795
# [epoch9, itr12000] loss: 0.798
# Epoch=9 Test Accuracy=59.120
# [epoch10, itr 2000] loss: 0.719
# [epoch10, itr 4000] loss: 0.733
# [epoch10, itr 6000] loss: 0.740
# [epoch10, itr 8000] loss: 0.770
# [epoch10, itr10000] loss: 0.764
# [epoch10, itr12000] loss: 0.795
# Epoch=10 Test Accuracy=59.830
# Finished Training
# [epoch1, itr 2000] loss: 0.643
# Epoch=1 Test Accuracy=60.320
# [epoch2, itr 2000] loss: 0.596
# Epoch=2 Test Accuracy=60.500
# [epoch3, itr 2000] loss: 0.579
# Epoch=3 Test Accuracy=60.270
# [epoch4, itr 2000] loss: 0.558
# Epoch=4 Test Accuracy=60.020
# [epoch5, itr 2000] loss: 0.541
# Epoch=5 Test Accuracy=60.000
# [epoch6, itr 2000] loss: 0.526
# Epoch=6 Test Accuracy=59.970
# [epoch7, itr 2000] loss: 0.519
# Epoch=7 Test Accuracy=59.740
# [epoch8, itr 2000] loss: 0.501
# Epoch=8 Test Accuracy=59.980
# [epoch9, itr 2000] loss: 0.496
# Epoch=9 Test Accuracy=59.770
# [epoch10, itr 2000] loss: 0.473
# Epoch=10 Test Accuracy=59.580
# Finished Training
# Epoch=1 Test Accuracy=59.740
# Epoch=2 Test Accuracy=59.500
# Epoch=3 Test Accuracy=59.620
# Epoch=4 Test Accuracy=59.540
# Epoch=5 Test Accuracy=59.610
# Epoch=6 Test Accuracy=59.620
# Epoch=7 Test Accuracy=59.570
# Epoch=8 Test Accuracy=59.570
# Epoch=9 Test Accuracy=59.720
# Epoch=10 Test Accuracy=59.610
# Finished Training
# Epoch=1 Test Accuracy=59.560
# Epoch=2 Test Accuracy=59.430
# Epoch=3 Test Accuracy=59.500
# Epoch=4 Test Accuracy=59.520
# Epoch=5 Test Accuracy=59.430
# Epoch=6 Test Accuracy=59.430
# Epoch=7 Test Accuracy=59.430
# Epoch=8 Test Accuracy=59.410
# Epoch=9 Test Accuracy=59.390
# Epoch=10 Test Accuracy=59.430
# Finished Training

# %% [markdown]
# #Additional code to explore the dataset and the trained model

# %%
# Show some random training images

import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.size())
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# torch.Size([256, 3, 32, 32])
#  frog   cat  deer  frog

# %%
# Test the network on some test images

dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))

# The outputs are energies for the 10 classes.
# The higher the energy for a class, the more the network
# thinks that the image is of the particular class.
# So, let's get the index of the highest energy:
if CUDA:
  images = images.cuda()
  labels = labels.cuda()
else:
  images = images.cpu()
  labels =labels.cpu()
outputs = net(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship  ship

# %%
# Lets check what are the classes that performed well, and the classes that did
# not perform well:

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for images, labels in testloader:
        if CUDA:
          images =images.cuda()
          labels =labels.cuda()
        else:
          images =images.cpu()
          labels =labels.cpu()

        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 56 %
# Accuracy of   car : 76 %
# Accuracy of  bird : 53 %
# Accuracy of   cat : 40 %
# Accuracy of  deer : 30 %
# Accuracy of   dog : 46 %
# Accuracy of  frog : 61 %
# Accuracy of horse : 66 %
# Accuracy of  ship : 80 %
# Accuracy of truck : 82 %
